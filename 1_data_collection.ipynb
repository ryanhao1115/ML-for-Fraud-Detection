# %% [markdown]
# ## Data collection and cleaning
# 1. Explore datasets, first round filtering data fields.
# 2. Rename columns.
# 3. Combine datasets into one single table.

# %%
import pandas as pd

# %%
df = pd.read_excel('may.XLSX')

# %%
df.head()
# Out:
#          下订方                下订方名             描述      营业担当 营业担当名    业务担当  \
# 0   G152004M  大金空调技术(中国)有限公司(南京)  2111305649+运费  PJ024907   朱振庭  132001
# 1  A13030128        常州雨沐冷暖设备有限公司      淮安水沐君悦售楼处  PJ017295   余学龙  110110
# 2    G002017   大金（中国）投资有限公司南京分公司      C19050029  PJ013183    丁涛  110106
# 3    G002017   大金（中国）投资有限公司南京分公司      C19050063  PJ050038    韩睿  110106
# 4    G002017   大金（中国）投资有限公司南京分公司      C19050038  PJ022866   徐兆龙  110106
#
#       联络所   联络所名  车号  提货人ID  ...     实际发货日期        出货日         交期     请求交货日期  \
# 0  720006  南京事务所 NaN    NaN  ...        NaT        NaT        NaT 2019-04-30
# 1  720016  徐州事务所 NaN    NaN  ...        NaT        NaT        NaT 2019-05-08
# 2  720036  临沂事务所 NaN    NaN  ... 2019-05-16 2019-05-14 2019-05-14 2019-05-10
# 3  720015  淮安事务所 NaN    NaN  ... 2019-05-28 2019-05-14 2019-05-14 2019-05-14
# 4  720014  盐城事务所 NaN    NaN  ... 2019-05-21 2019-05-14 2019-05-14 2019-05-14
#
#     备注 拒绝原因 事业.1   机号 售达方特殊依赖事项  利润中心
# ...

# %%
col = [0,3,5,6,16,22,24,25,27,38,40,42,43,50,53,65,76,77,83,86]

# %%
df_s = df.iloc[:,col]

# %%
df_s.head()
# Out:
#          下订方      营业担当    业务担当     联络所  传票类型  销售部门      销售传票编号  销售传票明细编号  \
# 0   G152004M  PJ024907  132001  720006  Z001  1050  1103720739        10
# 1  A13030128  PJ017295  110110  720016  Z016  1050  1103720871        10
# 2    G002017  PJ013183  110106  720036  Z008  1050  1103723744        10
# 3    G002017  PJ050038  110106  720015  Z008  1050  1103731799        10
# 4    G002017  PJ022866  110106  720014  Z008  1050  1103731803        10
#
#             品目  明细数量         净值     不含税单价    传票情况  明细数量(出货) 最终出货方行业      退货理由  \
# 0      FREIGHT     1    1000.00   1000.00    完成请求         0    AA01       NaN
# 1    RSQ500BBY     4  130973.44  32743.36    完成请求         0    AX01  32：业务　担当
# 2   DAM602B51M     4  131681.44  32920.36  完成库存确认         4    AA01       NaN
# 3  DCM601A621M     7   43362.83   6194.69  完成库存确认         7    AA01       NaN
# 4  DCM601A621M     7   43362.83   6194.69  完成库存确认         7    AA01       NaN
#
#          特贩申请No     销售单价     实际发货日期     请求交货日期
# ...
